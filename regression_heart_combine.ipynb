# %%
import numpy as np
import pandas as pd
data = pd.read_csv("E:/practical assingment materials/ml/Assi material/Heart.csv")
data
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed   No
# 1        1      1.5      2  3.0      normal  Yes
# 2        1      2.6      2  2.0  reversable  Yes
# 3        0      3.5      3  0.0      normal   No
# 4        0      1.4      1  0.0      normal   No
# ..     ...      ...    ...  ...         ...  ...
# 298      0      1.2      2  0.0  reversable  Yes
# 299      0      3.4      2  2.0  reversable  Yes
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
# 302      0      0.0      1  NaN      normal   No
#
# [303 rows x 15 columns]

# %%
# Group by column name
# df = data.groupby('Thal').nunique()
# df

# %%
# Transform ChestPain & Thal string data to numeric data
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
data["ChestPain"]=le.fit_transform(data["ChestPain"])
data["Thal"]=le.fit_transform(data["Thal"].astype(str))
data["AHD"]=le.fit_transform(data["AHD"].astype(str))
data
# Out:
#      Unnamed: 0  Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1          3     145   233    1        2    150
# 1             2   67    1          0     160   286    0        2    108
# 2             3   67    1          0     120   229    0        2    129
# 3             4   37    1          1     130   250    0        0    187
# 4             5   41    0          2     130   204    0        2    172
# ..          ...  ...  ...        ...     ...   ...  ...      ...    ...
# 298         299   45    1          3     110   264    0        0    132
# 299         300   68    1          0     144   193    1        0    141
# 300         301   57    1          0     130   131    0        0    115
# 301         302   57    0          2     130   236    0        2    174
# 302         303   38    1          1     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca  Thal  AHD
# 0        0      2.3      3  0.0     0    0
# 1        1      1.5      2  3.0     2    1
# 2        1      2.6      2  2.0     3    1
# 3        0      3.5      3  0.0     2    0
# 4        0      1.4      1  0.0     2    0
# ..     ...      ...    ...  ...   ...  ...
# 298      0      1.2      2  0.0     3    1
# 299      0      3.4      2  2.0     3    1
# 300      1      1.2      2  1.0     3    1
# 301      0      0.0      2  1.0     2    1
# 302      0      0.0      1  NaN     2    0
#
# [303 rows x 15 columns]

# %%
# Removing null values
null_val = ['Age','Sex','ChestPain','RestBP','Chol','Fbs','RestECG','MaxHR','Oldpeak','Slope','Ca','Thal']
for col in null_val:
    data[col] = data[col].replace(0, np.nan)
    mean = int(data[col].mean(skipna=True))
    data[col] = data[col].replace(np.nan, mean)

data
# Out:
#      Unnamed: 0  Age  Sex  ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63  1.0        3.0     145   233  1.0      2.0    150
# 1             2   67  1.0        1.0     160   286  1.0      2.0    108
# 2             3   67  1.0        1.0     120   229  1.0      2.0    129
# 3             4   37  1.0        1.0     130   250  1.0      1.0    187
# 4             5   41  1.0        2.0     130   204  1.0      2.0    172
# ..          ...  ...  ...        ...     ...   ...  ...      ...    ...
# 298         299   45  1.0        3.0     110   264  1.0      1.0    132
# 299         300   68  1.0        1.0     144   193  1.0      1.0    141
# 300         301   57  1.0        1.0     130   131  1.0      1.0    115
# 301         302   57  1.0        2.0     130   236  1.0      2.0    174
# 302         303   38  1.0        1.0     138   175  1.0      1.0    173
#
#      ExAng  Oldpeak  Slope   Ca  Thal  AHD
# 0        0      2.3      3  1.0   2.0    0
# 1        1      1.5      2  3.0   2.0    1
# 2        1      2.6      2  2.0   3.0    1
# 3        0      3.5      3  1.0   2.0    0
# 4        0      1.4      1  1.0   2.0    0
# ..     ...      ...    ...  ...   ...  ...
# 298      0      1.2      2  1.0   3.0    1
# 299      0      3.4      2  2.0   3.0    1
# 300      1      1.2      2  1.0   3.0    1
# 301      0      1.0      2  1.0   2.0    1
# 302      0      1.0      1  1.0   2.0    0
#
# [303 rows x 15 columns]

# %%
# x = data[['Age','Sex','ChestPain','RestBP','Chol','Fbs','RestECG','MaxHR','Oldpeak','Slope','Ca','Thal']].values
# y = data['AHD'].values
X = data.iloc[:, [8,3,6]].values
y = data.iloc[:, 14].values

# %%
# divide data into training and testing dataset
from sklearn.model_selection import train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X, y, train_size = 0.80, random_state=0)

# %%
# prepare model
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(xTrain, yTrain)
# Out:
# LinearRegression()

# %%
# prediction
yPred = model.predict(xTest)
yPred
# Out:
# array([-0.00643801,  0.41931508,  0.87731736,  0.4721615 ,  0.48096924,
#         1.20320359,  1.05347208,  0.45454603,  0.99181792,  0.48977697,
#         0.56023886,  0.2666018 ,  0.75400905,  0.57785433,  0.29600678,
#         0.46335376,  0.44573829,  0.49858471,  0.25779407,  0.68354716,
#         0.27540954,  0.3488532 ,  0.5690466 ,  0.72758584,  0.19031395,
#         0.16971671,  0.17554268,  0.61308528,  0.98301019,  0.86850962,
#         0.8156632 ,  0.30481452,  0.3752764 ,  0.53381565,  0.32242999,
#         0.24898633,  0.33706369,  0.5690466 ,  0.41931508,  0.28421728,
#         0.11687029,  0.43977476,  0.54262339,  0.11388853,  0.2519681 ,
#         0.48977697,  0.3752764 , -0.03286122,  0.45454603,  0.39289188,
#         0.3752764 ,  0.39289188,  0.5690466 ,  0.33123772,  0.00819569,
#         0.31362225,  0.73639358,  0.30481452,  0.31362225,  0.5954698 ,
#         0.51620018])

# %%
from sklearn.metrics import r2_score
r2 = r2_score(yTest, yPred)
r2
# Out:
# 0.09083059763154733

# %%
# cross validation
accu = []
for i in range(1, 101):
    xTrain, xTest, yTrain, yTest = train_test_split(X, y, train_size=0.80, random_state=i)
    model = LinearRegression()
    model.fit(xTrain, yTrain)
    yPred = model.predict(xTest)
    r2 = r2_score(yTest, yPred)
    accu.append(r2)

accu_array = np.array(accu)
print(accu_array)
accu_array.max()
# Out:
# [ 0.21762094  0.24266129  0.18676974  0.12846513  0.23958433  0.08194613
#   0.19102105  0.30563418  0.23333553  0.13206717  0.1874308   0.23175608
#   0.30636735  0.18072288  0.20364636  0.04356872  0.20755596 -0.00331611
#   0.26251401  0.17666397  0.18195532  0.29269645  0.21299595  0.15802749
#   0.22586764  0.27971855  0.13267341  0.26847968  0.3093433   0.270838
#   0.18437704  0.11328914  0.24580369  0.12429506 -0.06103904  0.11327281
#   0.25075725  0.28046718  0.23045287  0.28132595  0.24742722  0.32779881
#   0.31550999  0.18251275  0.2536323   0.16800837  0.1967922   0.24981917
#   0.02673974  0.11878332  0.18873216  0.22879121  0.26442764  0.16326278
#   0.10935196  0.24320981  0.26254898  0.20274375  0.22219399  0.2336965
#   0.16625896  0.16389617  0.25667919  0.13561575 -0.00084216  0.05073441
#   0.16423413  0.11450838  0.08008359  0.10826112  0.15277249  0.17359972
#   0.28035414  0.15986291  0.19005605  0.05719424  0.1169715   0.19742042
#   0.18812572  0.10293337  0.04689989  0.16429737  0.09571108  0.1777486
#   0.09802356  0.18682925  0.19112439  0.21257925  0.10522351  0.17540659
#   0.08407892  0.22644529  0.177339    0.21216058  0.2187676   0.21509603
#   0.21884788  0.2409104   0.21107558  0.12853633]
# 0.3277988131620593
